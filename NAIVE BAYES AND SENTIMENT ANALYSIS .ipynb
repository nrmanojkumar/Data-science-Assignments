# %% [markdown]
# Data Exploration and Preprocessing

# %%
import pandas as pd

# %%
df = pd.read_csv('blogs_categories.csv')

# %%
df
# Out:
#        Unnamed: 0                                               Data  \
# 0               0  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:49...
# 1               1  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...
# 2               2  Newsgroups: alt.atheism\nPath: cantaloupe.srv....
# 3               3  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...
# 4               4  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...
# ...           ...                                                ...
# 19992       19992  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:54...
# 19993       19993  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:54...
# 19994       19994  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19995       19995  Xref: cantaloupe.srv.cs.cmu.edu talk.religion....
# 19996       19996  Xref: cantaloupe.srv.cs.cmu.edu talk.abortion:...
#
#                    Labels
# 0             alt.atheism
# 1             alt.atheism
# 2             alt.atheism
# 3             alt.atheism
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                                               Data       Labels
# 0           0  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:49...  alt.atheism
# 1           1  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism
# 2           2  Newsgroups: alt.atheism\nPath: cantaloupe.srv....  alt.atheism
# 3           3  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism
# 4           4  Xref: cantaloupe.srv.cs.cmu.edu alt.atheism:51...  alt.atheism

# %%
df.dtypes
# Out:
# Unnamed: 0     int64
# Data          object
# Labels        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19997 entries, 0 to 19996
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  19997 non-null  int64
#  1   Data        19997 non-null  object
#  2   Labels      19997 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 468.8+ KB

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0            0
# Data                  0
# Labels                0
# sentiment             0
# sentiment_category    0
# dtype: int64

# %%
# !pip install textblob
# Out:
# ...
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#     --------------------------------------- 10.2/626.3 kB ? eta -:--:--
#    ----- ---------------------------------- 81.9/626.3 kB 1.2 MB/s eta 0:00:01
#    ------------------------------ --------- 471.0/626.3 kB 4.2 MB/s eta 0:00:01
#    ---------------------------------------- 626.3/626.3 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from textblob import TextBlob

# %%
# Preprocess the data
df['Data'] = df['Data'].str.lower() 
df['Data'] = df['Data'].str.replace('[^\w\s]', '')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14984\982058322.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Data'] = df['Data'].str.replace('[^\w\s]', '')

# %% [markdown]
# Naive Bayes Model for Text Classification

# %%
# Perform feature extraction using TF-IDF
vectorizer = TfidfVectorizer(stop_words='english')
features = vectorizer.fit_transform(df['Data'])

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(features, df['Labels'], test_size=0.3, random_state=42)

# %%
# Implement a Naive Bayes classifier
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
# Make predictions on the test set
y_pred = clf.predict(X_test)

# %% [markdown]
# Sentiment Analysis

# %%
# Perform sentiment analysis on the blog post texts
df['sentiment'] = df['Data'].apply(lambda text: TextBlob(text).sentiment.polarity)

# %%
# Categorize them as positive, negative, or neutral
df['sentiment_category'] = df['sentiment'].apply(lambda sentiment: 'positive' if sentiment > 0 else ('negative' if sentiment < 0 else 'neutral'))

# %%
print(df['sentiment_category'].value_counts())
# Out:
# positive    14845
# negative     5141
# neutral        11
# Name: sentiment_category, dtype: int64

# %% [markdown]
# Evaluation

# %%
# Evaluate the performance of the Naive Bayes classifier
print(metrics.classification_report(y_test, y_pred))
# Out:
#                           precision    recall  f1-score   support
#
#              alt.atheism       0.73      0.81      0.77       274
#            comp.graphics       0.86      0.91      0.88       290
#  comp.os.ms-windows.misc       0.93      0.88      0.90       320
# comp.sys.ibm.pc.hardware       0.82      0.87      0.85       304
#    comp.sys.mac.hardware       0.89      0.94      0.91       296
#           comp.windows.x       0.97      0.92      0.95       293
#             misc.forsale       0.92      0.78      0.85       297
#                rec.autos       0.92      0.95      0.94       306
#          rec.motorcycles       0.99      0.97      0.98       317
#       rec.sport.baseball       1.00      0.99      0.99       290
#         rec.sport.hockey       0.97      0.99      0.98       301
#                sci.crypt       0.92      0.98      0.95       295
#          sci.electronics       0.91      0.87      0.89       318
# ...

# %%
# Accuracy
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.899
